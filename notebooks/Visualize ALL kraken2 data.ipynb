# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn3_unweighted
import glob
from collections import defaultdict

# %%
truss_tax_file_list = list(glob.glob("/home/Users/mt102/shared/KOMB/kraken2-trusses/*/truss.kraken2_report.txt"))
all_tax_file_list = list(glob.glob("/home/Users/ns58/KOMB2/PRJNA878603-kraken2-all/*kraken2_report.txt"))

# %%
truss_tax_file_list
# Out:
# ['/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907994-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907930-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908035-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908048-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907858-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908052-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907878-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908037-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907972-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908055-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907947-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908054-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908042-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907832-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907915-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907887-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907860-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907990-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907834-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907943-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907950-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907862-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908018-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907864-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907910-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907912-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907840-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907850-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907911-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907920-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907952-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907940-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907932-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907995-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907819-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907896-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907982-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907875-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907871-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907869-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907908-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908039-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907968-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907961-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908003-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907951-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908016-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907889-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907851-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907936-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907857-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908049-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907967-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907846-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907853-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908017-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907998-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907855-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907983-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908032-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907981-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907963-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908040-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907973-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907826-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908002-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907946-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907903-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907942-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907895-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908008-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907991-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907905-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908014-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907923-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908026-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908009-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907831-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907976-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907924-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907838-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907989-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907900-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907956-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908033-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908044-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907852-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907827-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907925-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907843-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907927-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907928-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908010-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907886-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907849-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907980-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907945-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907959-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908028-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907975-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907824-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908025-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907880-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908045-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907962-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907821-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907996-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907859-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908012-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907931-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907939-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907938-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907898-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907894-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908004-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907830-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907866-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907919-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907828-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907986-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907902-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907861-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907997-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907965-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907833-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908006-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907958-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908051-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907906-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908053-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907937-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907879-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907829-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908031-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907917-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907978-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907820-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907891-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907999-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907867-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907953-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907909-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907870-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908030-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907969-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907865-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907877-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907818-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907934-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908043-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907873-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907913-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907847-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907841-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907977-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907892-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907856-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908046-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908019-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907979-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907987-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907993-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907948-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908020-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907854-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907835-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908038-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908029-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907957-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907916-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907837-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908034-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907960-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907823-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908023-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907955-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907884-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907933-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908015-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907888-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907918-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908027-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907848-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907984-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907914-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907883-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908000-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908050-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908041-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907929-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907974-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908021-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908007-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907845-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907901-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907921-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908047-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907881-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907926-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907839-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907882-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908001-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907985-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907872-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907897-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908005-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907904-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907874-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907899-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907966-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907885-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907836-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907970-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907844-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907949-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907868-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907922-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907941-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907988-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908011-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907842-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908024-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907876-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908036-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907964-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907822-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907907-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907935-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907890-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907954-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908022-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24908013-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907944-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907825-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907893-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907863-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907992-k51-l150-c2/truss.kraken2_report.txt',
#  '/home/Users/mt102/shared/KOMB/kraken2-trusses/SRR24907971-k51-l150-c2/truss.kraken2_report.txt']

# %%
truss_tax_profiles = {}
for file in all_tax_file_list:
    run_name = file.split('/')[-1].split(".")[0]
    truss_tax_profiles[run_name] = pd.read_csv(f"{file}", 
                                    sep='\t', header=None)

# %%
truss_tax_profiles["SRR24907994"]
# Out:
#           0       1       2   3        4  \
# 0     45.90  145131  145131   U        0
# 1     54.10  171044      96   R        1
# 2     54.05  170893      83  R1   131567
# 3     53.62  169540    1658   D        2
# 4     28.54   90226     481  D1  1783272
# ...     ...     ...     ...  ..      ...
# 7223   0.00       1       0   O  2732554
# 7224   0.00       1       0   F   549779
# 7225   0.00       1       0  F1   985780
# 7226   0.00       1       0   G  2094720
# 7227   0.00       1       1   S  2126985
#
#                                              5
# 0                                 unclassified
# 1                                         root
# 2                           cellular organisms
# 3                                     Bacteria
# 4                          Terrabacteria group
# ...                                        ...
# 7223                             Imitervirales
# 7224                               Mimiviridae
# 7225                  unclassified Mimiviridae
# 7226                                Tupanvirus
# 7227                      Tupanvirus soda lake
#
# [7228 rows x 6 columns]

# %%
metadata = pd.read_csv("/home/Users/ns58/KOMB2/Data/PRJNA878603_SraRunTable.txt")
metadata_short = metadata[["Run", "gender", "RACE", "illness_duration", "study_ptorhc"]]
metadata_short = metadata_short.set_index("Run")
metadata_short
# Out:
#              gender   RACE illness_duration study_ptorhc
# Run
# SRR24907820    male  White          Control      Control
# SRR24907822  female  White             Long        MECFS
# SRR24907824  female  White             Long        MECFS
# SRR24907826  female  White             Long        MECFS
# SRR24907827  female  White          Control      Control
# ...             ...    ...              ...          ...
# SRR24908035  female  White            Short        MECFS
# SRR24908039    male  White            Short        MECFS
# SRR24908045  female  White          Control      Control
# SRR24908050  female  White          Control      Control
# SRR24908054    male  White            Short        MECFS
#
# [238 rows x 4 columns]

# %%
control_truss_tax_profiles = {run: truss_tax_profiles[run] for run in truss_tax_profiles \
                              if metadata_short.at[run, "illness_duration"] == "Control"}
short_truss_tax_profiles   = {run: truss_tax_profiles[run] for run in truss_tax_profiles \
                              if metadata_short.at[run, "illness_duration"] == "Short"}
long_truss_tax_profiles    = {run: truss_tax_profiles[run] for run in truss_tax_profiles \
                              if metadata_short.at[run, "illness_duration"] == "Long"}

# %%
truss_control_entropy = [stats.entropy(control_truss_tax_profiles[run][control_truss_tax_profiles[run][3] == 'S'][0]) \
                         for run in control_truss_tax_profiles]
truss_short_entropy = [stats.entropy(short_truss_tax_profiles[run][short_truss_tax_profiles[run][3] == 'S'][0]) \
                       for run in short_truss_tax_profiles]
truss_long_entropy = [stats.entropy(long_truss_tax_profiles[run][long_truss_tax_profiles[run][3] == 'S'][0]) \
                      for run in long_truss_tax_profiles]

# %%
fig, axs = plt.subplots(1, 1, sharey=True, figsize=(5, 5))

axs.boxplot([truss_control_entropy, truss_short_entropy, truss_long_entropy])

w, p_val_control_short = stats.ttest_ind(truss_control_entropy, truss_short_entropy, equal_var=False)
w, p_val_control_long = stats.ttest_ind(truss_control_entropy, truss_long_entropy, equal_var=False)
w, p_val_short_long = stats.ttest_ind(truss_short_entropy, truss_long_entropy, equal_var=False)

axs.hlines([4.5, 5.1, 5.7], [1, 2, 1], [2, 3, 3], 
           lw=2, colors='k')
axs.text(1.5, 4.7, f"p-val: {p_val_control_short:.3f}",
         ha="center", fontsize=14)
axs.text(2.5, 5.3, f"p-val: {p_val_short_long:.3f}",
         ha="center", fontsize=14)
axs.text(2., 5.9, f"p-val: {p_val_control_long:.3f}",
         ha="center", fontsize=14)

axs.set_title("Alpha diversity of unitigs found\ngeneral [Species]", fontsize=18)

axs.set_ylabel("Shannon entropy", fontsize=18)
axs.set_yticks(np.arange(.5, 6.6, .5))
axs.set_yticklabels(np.arange(.5, 6.6, .5), fontsize=16)

axs.set_xticks([1, 2, 3])
axs.set_xticklabels(["Control", "ME/CFS\n(Short)", "ME/CFS\n(Long)"],
                    fontsize=18)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.savefig("PRJNA878603-MECFS-ALL-entropy-S-v-condition-dpi300.png", dpi=300)
plt.show()

# %%
control_sets = [set(control_truss_tax_profiles[run][control_truss_tax_profiles[run][3] == 'S'][4]) \
                for run in control_truss_tax_profiles]
short_sets   = [set(short_truss_tax_profiles[run][short_truss_tax_profiles[run][3] == 'S'][4]) \
                for run in short_truss_tax_profiles]
long_sets    = [set(long_truss_tax_profiles[run][long_truss_tax_profiles[run][3] == 'S'][4]) \
                for run in long_truss_tax_profiles]

control_pool_set = set()
short_pool_set   = set()
long_pool_set    = set()

for taxids in control_sets:
    control_pool_set |= taxids
    
for taxids in short_sets:
    short_pool_set |= taxids
    
for taxids in long_sets:
    long_pool_set |= taxids

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ids = ['100', '010', '001',
       '110', '101', '011', '111']

v = venn3_unweighted([control_pool_set, short_pool_set, long_pool_set],
                     set_labels=["Control", "ME/CFS (Short)", "ME/CFS (Long)"])

p = v.get_patch_by_id('100')
p.set_color('#117733')

p = v.get_patch_by_id('010')
p.set_color('#cc6677')

p = v.get_patch_by_id('001')
p.set_color('#ddcc77')

p = v.get_patch_by_id('110')
p.set_color('#994455')

p = v.get_patch_by_id('101')
p.set_color('#999933')

p = v.get_patch_by_id('011')
p.set_color('#ee8866')

p = v.get_patch_by_id('111')
p.set_color('#888888')

for i in ids:
    l = v.get_label_by_id(i)
    l.set_fontsize(16)

for l in v.set_labels:
    l.set_fontsize(18)
    
plt.tight_layout()
fig.savefig("PRJNA878603-MECFS-ALL-venn-S-v-condition-dpi300.png", dpi=300)
plt.show()

# %%
truss_control_entropy = [stats.entropy(control_truss_tax_profiles[run][control_truss_tax_profiles[run][3] == 'G'][0]) \
                         for run in control_truss_tax_profiles]
truss_short_entropy = [stats.entropy(short_truss_tax_profiles[run][short_truss_tax_profiles[run][3] == 'G'][0]) \
                       for run in short_truss_tax_profiles]
truss_long_entropy = [stats.entropy(long_truss_tax_profiles[run][long_truss_tax_profiles[run][3] == 'G'][0]) \
                      for run in long_truss_tax_profiles]

# %%
fig, axs = plt.subplots(1, 1, sharey=True, figsize=(5, 5))

axs.boxplot([truss_control_entropy, truss_short_entropy, truss_long_entropy])

w, p_val_control_short = stats.ttest_ind(truss_control_entropy, truss_short_entropy, equal_var=False)
w, p_val_control_long = stats.ttest_ind(truss_control_entropy, truss_long_entropy, equal_var=False)
w, p_val_short_long = stats.ttest_ind(truss_short_entropy, truss_long_entropy, equal_var=False)

axs.hlines([4.5, 5.1, 5.7], [1, 2, 1], [2, 3, 3], 
           lw=2, colors='k')
axs.text(1.5, 4.7, f"p-val: {p_val_control_short:.3f}",
         ha="center", fontsize=14)
axs.text(2.5, 5.3, f"p-val: {p_val_short_long:.3f}",
         ha="center", fontsize=14)
axs.text(2., 5.9, f"p-val: {p_val_control_long:.3f}",
         ha="center", fontsize=14)

axs.set_title("Alpha diversity of unitigs found\ngeneral [Genus]", fontsize=18)

axs.set_ylabel("Shannon entropy", fontsize=18)
axs.set_yticks(np.arange(.5, 6.6, .5))
axs.set_yticklabels(np.arange(.5, 6.6, .5), fontsize=16)

axs.set_xticks([1, 2, 3])
axs.set_xticklabels(["Control", "ME/CFS\n(Short)", "ME/CFS\n(Long)"],
                    fontsize=18)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.savefig("PRJNA878603-MECFS-ALL-entropy-G-v-condition-dpi300.png", dpi=300)
plt.show()

# %%
control_sets = [set(control_truss_tax_profiles[run][control_truss_tax_profiles[run][3] == 'G'][4]) \
                for run in control_truss_tax_profiles]
short_sets   = [set(short_truss_tax_profiles[run][short_truss_tax_profiles[run][3] == 'G'][4]) \
                for run in short_truss_tax_profiles]
long_sets    = [set(long_truss_tax_profiles[run][long_truss_tax_profiles[run][3] == 'G'][4]) \
                for run in long_truss_tax_profiles]

control_pool_set = set()
short_pool_set   = set()
long_pool_set    = set()

for taxids in control_sets:
    control_pool_set |= taxids
    
for taxids in short_sets:
    short_pool_set |= taxids
    
for taxids in long_sets:
    long_pool_set |= taxids

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ids = ['100', '010', '001',
       '110', '101', '011', '111']

v = venn3_unweighted([control_pool_set, short_pool_set, long_pool_set],
                     set_labels=["Control", "ME/CFS (Short)", "ME/CFS (Long)"])

p = v.get_patch_by_id('100')
p.set_color('#117733')

p = v.get_patch_by_id('010')
p.set_color('#cc6677')

p = v.get_patch_by_id('001')
p.set_color('#ddcc77')

p = v.get_patch_by_id('110')
p.set_color('#994455')

p = v.get_patch_by_id('101')
p.set_color('#999933')

p = v.get_patch_by_id('011')
p.set_color('#ee8866')

p = v.get_patch_by_id('111')
p.set_color('#888888')

for i in ids:
    l = v.get_label_by_id(i)
    l.set_fontsize(16)

for l in v.set_labels:
    l.set_fontsize(18)
    
plt.tight_layout()
fig.savefig("PRJNA878603-MECFS-ALL-venn-G-v-condition-dpi300.png", dpi=300)
plt.show()
